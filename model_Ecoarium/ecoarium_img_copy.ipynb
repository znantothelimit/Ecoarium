# %%
import cv2
import numpy as np
from random import uniform
import tkinter as tk
from tkinter import filedialog, messagebox, simpledialog
import os
import shutil

dir_path = "Data_PlasticCup"
output_dir = "Data_PlasticCup"

def select_image():
    global selected_image_path
    selected_image_path = filedialog.askopenfilename(initialdir=dir_path, title="Select Image File")
    if selected_image_path:
        image_path_label.config(text=f"Selected Image: {selected_image_path}")

def select_output_dir():
    global output_dir
    output_dir = filedialog.askdirectory(initialdir=output_dir, title="Select Output Directory")
    if output_dir:
        output_dir_label.config(text=f"Output Directory: {output_dir}")

def copy_images_with_brightness_variation():
    if selected_image_path and output_dir:
        try:
            # 파일 이름 추출
            file_name = os.path.basename(selected_image_path)
            name, ext = os.path.splitext(file_name)

            # 이미지 읽기
            img = cv2.imread(selected_image_path)

            # 복사할 이미지 개수 입력 받기
            num_outputs = simpledialog.askinteger("Number of Copies", "Enter the number of copies to create:", initialvalue=10)
            if num_outputs is None:  # 취소 버튼을 누르면 중단
                return

            for i in range(num_outputs):
                # 랜덤 밝기 조절
                brightness_factor = uniform(-0.4, 0)

                # 밝기 조절
                adjusted_img = cv2.convertScaleAbs(img, alpha=1.0, beta=brightness_factor * 255)

                # 출력 이미지 저장
                output_path = os.path.join(output_dir, f"{name}_{i}{ext}")
                cv2.imwrite(output_path, adjusted_img)
                print(f"Output {i + 1}/{num_outputs} saved: {output_path}")

            messagebox.showinfo("Success", f"Images copied to {output_dir}")
        except Exception as e:
            messagebox.showerror("Error", f"An error occurred: {e}")
    else:
        messagebox.showerror("Error", "Please select an image and an output directory.")

# Tkinter 창 생성
root = tk.Tk()
root.title("Select Image and Output Directory")

# 이미지 파일 선택 버튼
select_image_button = tk.Button(root, text="Select Image", command=select_image)
select_image_button.pack(pady=10)

# 이미지 경로 표시 라벨
image_path_label = tk.Label(root, text="Selected Image: ")
image_path_label.pack()

# 출력 디렉토리 선택 버튼
select_output_dir_button = tk.Button(root, text="Select Output Directory", command=select_output_dir)
select_output_dir_button.pack(pady=5)

# 출력 디렉토리 경로 표시 라벨
output_dir_label = tk.Label(root, text="Output Directory: ")
output_dir_label.pack()

# 이미지 복사 버튼
copy_button = tk.Button(root, text="Copy Images with Brightness Variation", command=copy_images_with_brightness_variation)
copy_button.pack(pady=10)

root.mainloop()
# Out:
# Output 1/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_0.jpg
# Output 2/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_1.jpg
# Output 3/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_2.jpg
# Output 4/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_3.jpg
# Output 5/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_4.jpg
# Output 6/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_5.jpg
# Output 7/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_6.jpg
# Output 8/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_7.jpg
# Output 9/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_8.jpg
# Output 10/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_9.jpg
# Output 11/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_10.jpg
# Output 12/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_11.jpg
# Output 13/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_12.jpg
# Output 14/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_13.jpg
# Output 15/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_14.jpg
# Output 16/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_15.jpg
# Output 17/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_16.jpg
# Output 18/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_17.jpg
# Output 19/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_18.jpg
# Output 20/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_19.jpg
# Output 21/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_20.jpg
# Output 22/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_21.jpg
# Output 23/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_22.jpg
# Output 24/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_23.jpg
# Output 25/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_24.jpg
# Output 26/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_25.jpg
# Output 27/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_26.jpg
# Output 28/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_27.jpg
# Output 29/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_28.jpg
# Output 30/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_29.jpg
# Output 31/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_30.jpg
# Output 32/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_31.jpg
# Output 33/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_32.jpg
# Output 34/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_33.jpg
# Output 35/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_34.jpg
# Output 36/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_35.jpg
# Output 37/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_36.jpg
# Output 38/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_37.jpg
# Output 39/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_38.jpg
# Output 40/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_39.jpg
# Output 41/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_40.jpg
# Output 42/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_41.jpg
# Output 43/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_42.jpg
# Output 44/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_43.jpg
# Output 45/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_44.jpg
# Output 46/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_45.jpg
# Output 47/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_46.jpg
# Output 48/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_47.jpg
# Output 49/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_48.jpg
# Output 50/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/clean\image-09142836_49.jpg
# Output 1/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_0.jpg
# Output 2/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_1.jpg
# Output 3/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_2.jpg
# Output 4/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_3.jpg
# Output 5/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_4.jpg
# Output 6/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_5.jpg
# Output 7/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_6.jpg
# Output 8/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_7.jpg
# Output 9/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_8.jpg
# Output 10/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_9.jpg
# Output 11/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_10.jpg
# Output 12/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_11.jpg
# Output 13/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_12.jpg
# Output 14/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_13.jpg
# Output 15/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_14.jpg
# Output 16/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_15.jpg
# Output 17/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_16.jpg
# Output 18/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_17.jpg
# Output 19/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_18.jpg
# Output 20/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_19.jpg
# Output 21/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_20.jpg
# Output 22/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_21.jpg
# Output 23/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_22.jpg
# Output 24/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_23.jpg
# Output 25/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_24.jpg
# Output 26/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_25.jpg
# Output 27/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_26.jpg
# Output 28/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_27.jpg
# Output 29/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_28.jpg
# Output 30/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_29.jpg
# Output 31/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_30.jpg
# Output 32/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_31.jpg
# Output 33/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_32.jpg
# Output 34/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_33.jpg
# Output 35/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_34.jpg
# Output 36/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_35.jpg
# Output 37/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_36.jpg
# Output 38/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_37.jpg
# Output 39/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_38.jpg
# Output 40/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_39.jpg
# Output 41/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_40.jpg
# Output 42/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_41.jpg
# Output 43/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_42.jpg
# Output 44/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_43.jpg
# Output 45/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_44.jpg
# Output 46/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_45.jpg
# Output 47/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_46.jpg
# Output 48/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_47.jpg
# Output 49/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_48.jpg
# Output 50/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09142658_49.jpg
# Output 1/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_0.jpg
# Output 2/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_1.jpg
# Output 3/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_2.jpg
# Output 4/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_3.jpg
# Output 5/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_4.jpg
# Output 6/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_5.jpg
# Output 7/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_6.jpg
# Output 8/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_7.jpg
# Output 9/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_8.jpg
# Output 10/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_9.jpg
# Output 11/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_10.jpg
# Output 12/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_11.jpg
# Output 13/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_12.jpg
# Output 14/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_13.jpg
# Output 15/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_14.jpg
# Output 16/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_15.jpg
# Output 17/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_16.jpg
# Output 18/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_17.jpg
# Output 19/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_18.jpg
# Output 20/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_19.jpg
# Output 21/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_20.jpg
# Output 22/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_21.jpg
# Output 23/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_22.jpg
# Output 24/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_23.jpg
# Output 25/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_24.jpg
# Output 26/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_25.jpg
# Output 27/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_26.jpg
# Output 28/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_27.jpg
# Output 29/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_28.jpg
# Output 30/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_29.jpg
# Output 31/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_30.jpg
# Output 32/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_31.jpg
# Output 33/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_32.jpg
# Output 34/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_33.jpg
# Output 35/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_34.jpg
# Output 36/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_35.jpg
# Output 37/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_36.jpg
# Output 38/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_37.jpg
# Output 39/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_38.jpg
# Output 40/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_39.jpg
# Output 41/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_40.jpg
# Output 42/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_41.jpg
# Output 43/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_42.jpg
# Output 44/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_43.jpg
# Output 45/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_44.jpg
# Output 46/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_45.jpg
# Output 47/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_46.jpg
# Output 48/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_47.jpg
# Output 49/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_48.jpg
# Output 50/50 saved: C:/vscode_kcy/Ecoarium/Data_PlasticCup/ng\image-09143213_49.jpg
