# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data = []
labels = []

# Clean 폴더 이미지 불러오기
clean_dir = 'Data_PlasticCup/clean'
for filename in os.listdir(clean_dir):
    img = cv2.imread(os.path.join(clean_dir, filename))
    img = cv2.resize(img, (128, 128))
    data.append(img)
    labels.append(0)  # 0 = 깨끗한 컵

# NG 폴더 이미지 불러오기
ng_dir = 'Data_PlasticCup/ng'
for filename in os.listdir(ng_dir):
    img = cv2.imread(os.path.join(ng_dir, filename))
    img = cv2.resize(img, (128, 128))
    data.append(img)
    labels.append(1)  # 1 = 더러운 컵

# 데이터 분할
x_train, x_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
# 모델 정의
model = Sequential()

# 컨볼루션 레이어 1
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D((2, 2)))

# 컨볼루션 레이어 2 
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# 컨볼루션 레이어 3
model.add(Conv2D(128, (3, 3), activation='relu')) 
model.add(MaxPooling2D((2, 2)))

# fully connected 레이어
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 데이터를 NumPy 배열로 변환
x_train = np.array(x_train)
y_train = np.array(y_train)
x_val = np.array(x_val)
y_val = np.array(y_val)

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=50, batch_size=16)

# 모델 저장
model.save('plastic_cup_classifier.h5')
# Out:
# c:\Users\lavie\.conda\envs\ENV00\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.5417 - loss: 76.7256 - val_accuracy: 0.7872 - val_loss: 2.7668
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6425 - loss: 2.6204 - val_accuracy: 0.7872 - val_loss: 0.3762
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7238 - loss: 0.6136 - val_accuracy: 0.9787 - val_loss: 0.1216
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8273 - loss: 0.4228 - val_accuracy: 0.9787 - val_loss: 0.3121
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9626 - loss: 0.1613 - val_accuracy: 1.0000 - val_loss: 9.2173e-04
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9566 - loss: 0.1994 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9688 - loss: 0.0640 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9784 - loss: 0.0390 - val_accuracy: 1.0000 - val_loss: 1.4148e-04
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9721 - loss: 0.0930 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9824 - loss: 0.0754 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9759 - loss: 0.0474 - val_accuracy: 1.0000 - val_loss: 2.7659e-04
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9853 - loss: 0.0503 - val_accuracy: 1.0000 - val_loss: 6.4780e-04
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 2.1589e-08
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9597 - loss: 0.3388 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9666 - loss: 0.1326 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9887 - loss: 0.0487 - val_accuracy: 1.0000 - val_loss: 0.0739
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9015 - loss: 0.2954 - val_accuracy: 1.0000 - val_loss: 0.0874
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9793 - loss: 0.0692 - val_accuracy: 1.0000 - val_loss: 9.0689e-06
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9813 - loss: 0.1190 - val_accuracy: 1.0000 - val_loss: 1.9837e-04
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9983 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9947 - loss: 0.0636 - val_accuracy: 1.0000 - val_loss: 1.5087e-05
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9707 - loss: 0.1555 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9965 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9965 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 2.6823e-06
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9766 - loss: 0.1142 - val_accuracy: 1.0000 - val_loss: 4.3064e-06
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9408 - loss: 0.1905 - val_accuracy: 0.9787 - val_loss: 0.0289
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9741 - loss: 0.1421 - val_accuracy: 1.0000 - val_loss: 9.2124e-04
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 1.3367e-04
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 3.3582e-04
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 4.0193e-05
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 7.6299e-04
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 4.7607e-06
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9947 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 4.9256e-06
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.8298e-04 - val_accuracy: 1.0000 - val_loss: 5.2148e-07
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 5.3304e-04 - val_accuracy: 1.0000 - val_loss: 3.6479e-07
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9865 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.0754e-11
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9890 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 6.9732e-04
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 7.1448e-05
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9992 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0242
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 4.4311e-09
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 6.9568e-05 - val_accuracy: 1.0000 - val_loss: 3.0475e-08
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9846 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 6.7019e-07
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 3.5945e-04 - val_accuracy: 1.0000 - val_loss: 1.7866e-10
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 4.7168e-06 - val_accuracy: 1.0000 - val_loss: 2.9512e-12
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 5.6152e-06 - val_accuracy: 1.0000 - val_loss: 3.4699e-13
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.9326e-04 - val_accuracy: 1.0000 - val_loss: 4.1434e-15
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# 모델 불러오기
from tensorflow.keras.models import load_model
model = load_model('plastic_cup_classifier.h5')

# 테스트 데이터셋 준비
x_test = np.array(x_val)
y_test = np.array(y_val)

# 모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc * 100:.2f}%')

# 예측값 구하기
y_pred = (model.predict(x_test) > 0.5).astype(int)

# 정확도 계산
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy (using sklearn.metrics): {accuracy * 100:.2f}%')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 - 0s - 87ms/step - accuracy: 1.0000 - loss: 4.1434e-15
# Test accuracy: 100.00%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Accuracy (using sklearn.metrics): 100.00%
